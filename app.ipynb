# %%
from typing import TypedDict, Annotated, Optional
from langgraph.graph import add_messages, StateGraph, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.memory import MemorySaver
from uuid import uuid4
import json

load_dotenv()

model = ChatOpenAI(model="gpt-4o")

# %%
search_tool = TavilySearchResults(max_results=4)

tools = [search_tool]

memory = MemorySaver()
# Out:
# /var/folders/2t/gftqwtk579jcc7_0379k_f900000gn/T/ipykernel_24272/3363489544.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-tavily package and should be used instead. To use it run `pip install -U :class:`~langchain-tavily` and import as `from :class:`~langchain_tavily import TavilySearch``.
#   search_tool = TavilySearchResults(max_results=4)

# %%
llm_with_tools = model.bind_tools(tools=tools)

# %%
from langchain_core.messages import AIMessage, HumanMessage, ToolMessage

class State(TypedDict):
    messages: Annotated[list, add_messages]

async def model(state: State):
    result = await llm_with_tools.ainvoke(state["messages"])
    return {
        "messages": [result], 
    }

async def tools_router(state: State):
    last_message = state["messages"][-1]

    if(hasattr(last_message, "tool_calls") and len(last_message.tool_calls) > 0):
        return "tool_node"
    else: 
        return END
    
async def tool_node(state):
    """Custom tool node that handles tool calls from the LLM."""
    # Get the tool calls from the last message
    tool_calls = state["messages"][-1].tool_calls
    
    # Initialize list to store tool messages
    tool_messages = []
    
    # Process each tool call
    for tool_call in tool_calls:
        tool_name = tool_call["name"]
        tool_args = tool_call["args"]
        tool_id = tool_call["id"]
        
        # Handle the search tool
        if tool_name == "tavily_search_results_json":
            # Execute the search tool with the provided arguments
            search_results = await search_tool.ainvoke(tool_args)
            
            # Create a ToolMessage for this result
            tool_message = ToolMessage(
                content=str(search_results),
                tool_call_id=tool_id,
                name=tool_name
            )
            
            tool_messages.append(tool_message)
    
    # Add the tool messages to the state
    return {"messages": tool_messages}

graph_builder = StateGraph(State)

graph_builder.add_node("model", model)
graph_builder.add_node("tool_node", tool_node)
graph_builder.set_entry_point("model")

graph_builder.add_conditional_edges("model", tools_router)
graph_builder.add_edge("tool_node", "model")

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API
        )
    )
)

# %%
config = {
    "configurable": {
        "thread_id": 5
    }
}

response = await graph.ainvoke({
    "messages": [HumanMessage(content="When is the next spacex launch?")], 
}, config=config)

response
# Out:
# {'messages': [HumanMessage(content='Hi I am Apurv?', additional_kwargs={}, response_metadata={}, id='0065b140-124c-499d-a9c3-cfc95d6b9c24'),
#   AIMessage(content='Hello Apurv! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 86, 'total_tokens': 99, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': None, 'id': 'chatcmpl-BsIpPyrfQ69iWECcpkuoyDSZSCgGY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--c9454735-ffbd-4204-86a5-a76f741f654a-0', usage_metadata={'input_tokens': 86, 'output_tokens': 13, 'total_tokens': 99, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='What is my name?', additional_kwargs={}, response_metadata={}, id='304470fb-74e1-4aca-b62a-6aae9fb256cd'),
#   AIMessage(content='Your name is Apurv. How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 111, 'total_tokens': 126, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': None, 'id': 'chatcmpl-BsIpdcSaIl1IddIKzt1VCUm1jdKb3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--72036aec-fc8a-496e-8b88-5658ea015696-0', usage_metadata={'input_tokens': 111, 'output_tokens': 15, 'total_tokens': 126, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='562b6412-e9f9-4cd0-bb84-0edb3c4e58de'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_3yKcGEWz1TXIMIcVAWYdbkdB', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 141, 'total_tokens': 163, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': None, 'id': 'chatcmpl-BsIq66eWqxKRendA3c6oVDUxFIgho', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--1e547a07-dd7a-4dd9-b847-d34e16a8d4c4-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_3yKcGEWz1TXIMIcVAWYdbkdB', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 22, 'total_tokens': 163, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 --------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Wed • Jul 16th, 2025\\n\\n 6:05 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\n\\n\\n Date/Time May Change \\n\\n Fri • Jul 25th, 2025\\n\\n 5:54 AM UTC \\n\\n Vostochny Cosmodrome, Siberia, Russian Federation [...] GSLV Mk II ----------------------------------------------------\\n### Indian Space Research Organization\\n\\n Date/Time May Change \\n\\n Wed • Jul 30th, 2025\\n\\n 11:30 AM UTC \\n\\n Satish Dhawan Space Centre, India \\n\\nFalcon 9 Block 5 -----------------------------------------------------------------\\n### SpaceX\\n\\n Date/Time TBD \\n\\n Projected To Launch\\n\\n July, 2025 \\n\\n Cape Canaveral SFS, FL, USA \\n\\n\\n\\n Date/Time TBD \\n\\n Project ...
#   AIMessage(content="The next scheduled SpaceX launch is targeting July 31 for the Crew-11 astronaut mission. The launch will involve a Falcon 9 rocket from NASA's Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit. You can read more about it [here](https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss).", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 1319, 'total_tokens': 1419, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': None, 'id': 'chatcmpl-BsIqANtG1GDx4HZRDtqZPOfPwCI5t', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2a686257-1365-44ac-92b6-d8bd5e3a6dab-0', usage_metadata={'input_tokens': 1319, 'output_tokens': 100, 'total_tokens': 1419, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
config = {
    "configurable": {
        "thread_id": 8
    }
}

# Use async for to iterate over the async generator
async for event in graph.astream_events({
    "messages": [HumanMessage(content="When is the next spacex launch?")],
}, config=config, version="v2"):
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={})]}}, 'name': 'LangGraph', 'tags': [], 'run_id': '00960538-8468-4060-af22-1cad61cb05b5', 'metadata': {'thread_id': 8}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9')]}}, 'name': 'model', 'tags': ['graph:step:1'], 'run_id': '1beb6831-7338-466a-a09b-a8f706cbd8ff', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9')]]}}, 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'tavily_search_results_json', 'args': '', 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '{"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': '', 'args': {}, 'id': None, 'type': 'tool_call'}], tool_call_chunks=[{'name': None, 'args': '{"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'query', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': 'query', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'query', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '":"', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': '":"', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '":"', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'next', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': 'next', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'next', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ' Space', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': ' Space', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ' Space', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': 'X', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': 'X', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': 'X', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ' launch', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': ' launch', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ' launch', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': ' date', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': ' date', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': ' date', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': None, 'function': {'arguments': '"}', 'name': None}, 'type': None}]}, response_metadata={}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', invalid_tool_calls=[{'name': None, 'args': '"}', 'id': None, 'error': None, 'type': 'invalid_tool_call'}], tool_call_chunks=[{'name': None, 'args': '"}', 'id': None, 'index': 0, 'type': 'tool_call_chunk'}])}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892')}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}]), 'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9')]]}}, 'run_id': '09cb57e7-d6ea-4f60-85ab-bed966aaa892', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None, 'LANGSMITH_PROJECT': 'pr-nautical-prosecutor-94', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f16b4f0-dirty'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}])]}}, 'name': 'tools_router', 'tags': ['seq:step:3'], 'run_id': 'f8b3e881-bf57-4eee-814d-d542a7f227ee', 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chain_end', 'data': {'output': 'tool_node', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}])]}}, 'run_id': 'f8b3e881-bf57-4eee-814d-d542a7f227ee', 'name': 'tools_router', 'tags': ['seq:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'LANGSMITH_PROJECT': 'pr-nautical-prosecutor-94', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f16b4f0-dirty'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', '1beb6831-7338-466a-a09b-a8f706cbd8ff']}
# {'event': 'on_chain_stream', 'run_id': '1beb6831-7338-466a-a09b-a8f706cbd8ff', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea'}, 'data': {'chunk': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}])]}}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}])]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9')]}}, 'run_id': '1beb6831-7338-466a-a09b-a8f706cbd8ff', 'name': 'model', 'tags': ['graph:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:44629c73-f326-55df-ac53-4cb9b8ce52ea', 'LANGSMITH_PROJECT': 'pr-nautical-prosecutor-94', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f16b4f0-dirty'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5']}
# {'event': 'on_chain_stream', 'run_id': '00960538-8468-4060-af22-1cad61cb05b5', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'model': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}])]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}])]}}, 'name': 'tool_node', 'tags': ['graph:step:2'], 'run_id': 'c6922ff4-ff37-4113-b428-3b678b17553f', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:286c956d-f769-5980-86d7-b51b7f0df739'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5']}
# {'event': 'on_tool_start', 'data': {'input': {'query': 'next SpaceX launch date'}}, 'name': 'tavily_search_results_json', 'tags': ['seq:step:1'], 'run_id': 'ffcf9f50-8e8f-476b-84d8-9e0a5fcf084c', 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:286c956d-f769-5980-86d7-b51b7f0df739', 'checkpoint_ns': 'tool_node:286c956d-f769-5980-86d7-b51b7f0df739'}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', 'c6922ff4-ff37-4113-b428-3b678b17553f']}
# {'event': 'on_tool_end', 'data': {'output': [{'title': 'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...', 'url': 'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss', 'content': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA's Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX's most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX's next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX's next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", 'score': 0.8708723}, {'title': 'Launch Schedule - Spaceflight Now', 'url': 'https://spaceflightnow.com/launch-schedule/', 'content': 'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")', 'score': 0.850382}, {'title': 'Next Spaceflight | Rocket Launch Schedule', 'url': 'https://nextspaceflight.com/', 'content': 'Next Spaceflight | Rocket Launch Schedule\n\n===============\n\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\n\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\n\n SpaceX \n\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\n\n ASDS \n\nSun Jul 13, 2025 04:31 UTC\n\nSLC-40, Cape Canaveral SFS, Florida, USA \n\nDetails\n\n SpaceX \n\n##### Falcon 9 Block 5 | Starlink Group 15-2\n\n OCISLY \n\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \n\nDetails\n\n CASC \n\n##### Long March 7 | Tianzhou 9\n\nMon Jul 14, 2025 21:40 UTC\n\nLC-201, Wenchang Space Launch Site, China \n\nDetails\n\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\n\nImage 7: Get it on Google Play\n\nImage 8: Get it on the App Store\n\n### Latest News\n\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\n\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship', 'score': 0.8437023}, {'title': 'Space Launch Schedule & Live Videos: Stream Rockets Launches', 'url': 'https://www.spacelaunchschedule.com/', 'content': 'Falcon 9 Block 5 --------------------------------------------\n### SpaceX\n\n Date/Time May Change \n\n Sun • Jul 13th, 2025\n\n 4:31 AM UTC \n\n Cape Canaveral SFS, FL, USA \n\nFalcon 9 Block 5 --------------------------------------\n### SpaceX\n\n Date/Time May Change \n\n Wed • Jul 16th, 2025\n\n 6:05 AM UTC \n\n Cape Canaveral SFS, FL, USA \n\n\n\n Date/Time May Change \n\n Fri • Jul 25th, 2025\n\n 5:54 AM UTC \n\n Vostochny Cosmodrome, Siberia, Russian Federation [...] GSLV Mk II ----------------------------------------------------\n### Indian Space Research Organization\n\n Date/Time May Change \n\n Wed • Jul 30th, 2025\n\n 11:30 AM UTC \n\n Satish Dhawan Space Centre, India \n\nFalcon 9 Block 5 -----------------------------------------------------------------\n### SpaceX\n\n Date/Time TBD \n\n Projected To Launch\n\n July, 2025 \n\n Cape Canaveral SFS, FL, USA \n\n\n\n Date/Time TBD \n\n Projected To Launch\n\n Mon • Aug 25th, 2025 \n\n Baikonur Cosmodrome, Republic of Kazakhstan', 'score': 0.81770587}], 'input': {'query': 'next Spa ...
# {'event': 'on_chain_stream', 'run_id': 'c6922ff4-ff37-4113-b428-3b678b17553f', 'name': 'tool_node', 'tags': ['graph:step:2'], 'metadata': {'thread_id': 8, 'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:286c956d-f769-5980-86d7-b51b7f0df739'}, 'data': {'chunk': {'messages': [ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 --------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Wed • Jul 16th, 2025\\n\\n 6:05 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\n\\n\\n Date/Time May Change \\n\\n Fri • Jul 25th, 2025\\n\\n 5:54 AM UTC \\n\\n Vostochny Cosmodrome, Siberia, Russian Federation [...] GSLV Mk II -------------------------------------- ...
# {'event': 'on_chain_end', 'data': {'output': {'messages': [ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 --------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Wed • Jul 16th, 2025\\n\\n 6:05 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\n\\n\\n Date/Time May Change \\n\\n Fri • Jul 25th, 2025\\n\\n 5:54 AM UTC \\n\\n Vostochny Cosmodrome, Siberia, Russian Federation [...] GSLV Mk II ----------------------------------------------------\\n### Indian Space Research Organization\\n\\n Date/Time May Change \\n\\n Wed • Jul 30th, 2025\\n\\n 11:30 AM UTC \\n\\n Satish Dhawan Space Centre, India \\n\\nFalcon 9 Block 5 -----------------------------------------------------------------\\n### SpaceX\\n\\n Date/Time TBD \\n\\n Projected To Launch\\n\\n July, 2025 \\n\\n Cape Canaver ...
# {'event': 'on_chain_stream', 'run_id': '00960538-8468-4060-af22-1cad61cb05b5', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8}, 'data': {'chunk': {'tool_node': {'messages': [ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 --------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Wed • Jul 16th, 2025\\n\\n 6:05 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\n\\n\\n Date/Time May Change \\n\\n Fri • Jul 25th, 2025\\n\\n 5:54 AM UTC \\n\\n Vostochny Cosmodrome, Siberia, Russian Federation [...] GSLV Mk II ----------------------------------------------------\\n### Indian Space Research Organization\\n\\n Date/Time May Change \\n\\n Wed • Jul 30th, 2025\\n\\n 11:30 AM UTC \\n\\n Satish Dhawan Space Centre, India \\n\\nFalcon 9 Block 5 --------------------------------- ...
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}]), ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 ------- ...
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}]), ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 - ...
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run--e35382c1-9248-4348-a56b-febfeca6deae')}, 'run_id': 'e35382c1-9248-4348-a56b-febfeca6deae', 'name': 'ChatOpenAI', 'tags': ['seq:step:1'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:768f2c01-eaf3-f481-1bd6-8033c209c392', 'checkpoint_ns': 'model:768f2c01-eaf3-f481-1bd6-8033c209c392', 'ls_provider': 'openai', 'ls_model_name': 'gpt-4o', 'ls_model_type': 'chat', 'ls_temperature': None}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5', 'c10c1330-af75-48d0-b3a3-023f7079ddfa']}
# ...
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}]), ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalco ...
# {'event': 'on_chain_stream', 'run_id': 'c10c1330-af75-48d0-b3a3-023f7079ddfa', 'name': 'model', 'tags': ['graph:step:3'], 'metadata': {'thread_id': 8, 'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:768f2c01-eaf3-f481-1bd6-8033c209c392'}, 'data': {'chunk': {'messages': [AIMessage(content="The next SpaceX launch is scheduled for July 31, 2025. This launch is targeting the Crew-11 astronaut mission to the International Space Station (ISS) atop a Falcon 9 rocket from Launch Complex-39A at NASA's Kennedy Space Center in Florida. You can read more about it [here](https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss).", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--e35382c1-9248-4348-a56b-febfeca6deae')]}}, 'parent_ids': ['00960538-8468-4060-af22-1cad61cb05b5']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content="The next SpaceX launch is scheduled for July 31, 2025. This launch is targeting the Crew-11 astronaut mission to the International Space Station (ISS) atop a Falcon 9 rocket from Launch Complex-39A at NASA's Kennedy Space Center in Florida. You can read more about it [here](https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss).", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--e35382c1-9248-4348-a56b-febfeca6deae')]}, 'input': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}]), ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Ge ...
# {'event': 'on_chain_stream', 'run_id': '00960538-8468-4060-af22-1cad61cb05b5', 'name': 'LangGraph', 'tags': [], 'metadata': {'thread_id': 8, 'LANGSMITH_PROJECT': 'pr-nautical-prosecutor-94', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_ENDPOINT': 'https://api.smith.langchain.com', 'revision_id': 'f16b4f0-dirty'}, 'data': {'chunk': {'model': {'messages': [AIMessage(content="The next SpaceX launch is scheduled for July 31, 2025. This launch is targeting the Crew-11 astronaut mission to the International Space Station (ISS) atop a Falcon 9 rocket from Launch Complex-39A at NASA's Kennedy Space Center in Florida. You can read more about it [here](https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss).", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--e35382c1-9248-4348-a56b-febfeca6deae')]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='When is the next spacex launch?', additional_kwargs={}, response_metadata={}, id='f6231b53-7973-4531-9ae5-279f7e60e7b9'), AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'function': {'arguments': '{"query":"next SpaceX launch date"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-08-06', 'service_tier': 'default'}, id='run--09cb57e7-d6ea-4f60-85ab-bed966aaa892', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'next SpaceX launch date'}, 'id': 'call_NhI3xDrHUuODljGATknYQrnF', 'type': 'tool_call'}]), ToolMessage(content='[{\'title\': \'NASA, SpaceX targeting July 31 for launch of Crew-11 astronaut ...\', \'url\': \'https://www.space.com/space-exploration/international-space-station/nasa-spacex-targeting-july-31-for-launch-of-crew-11-astronaut-mission-to-iss\', \'content\': "NASA is targeting July 31 for the launch of its next astronaut mission with SpaceX. The flight, called Crew-11, will lift off atop a Falcon 9 rocket from Launch Complex-39A (LC-39A), at NASA\'s Kennedy Space Center in Florida, sending the Crew Dragon Endeavour to low Earth orbit (LEO). The flight will mark the sixth mission for Endeavour, making it SpaceX\'s most-flown Crew Dragon spacecraft. [...] specialist Tibor Kapu. Private Spaceflight SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom SpaceImage 8: A black and white SpaceX Falcon 9 rocket carrying the Ax-4 crew capsule on the launch pad with colorful clouds lit by twilight. Private Spaceflight SpaceX launching private Ax-4 astronaut mission to ISS early June 25: Watch live! [...] SpaceX\'s next private astronaut mission to ISS, Ax-4, to launch May 29 for Axiom Space", \'score\': 0.8708723}, {\'title\': \'Launch Schedule - Spaceflight Now\', \'url\': \'https://spaceflightnow.com/launch-schedule/\', \'content\': \'Image 6SpaceX launches its 500th Falcon 9 rocket July 1, 2025 [...] which, $256.6 million was awarded to SpaceX to provide launch services and other mission related costs. The 20-day launch window opens on July 5, 2028. [...] [[ July 1, 2025 ] SpaceX launches its 500th Falcon 9 rocket Falcon 9]( "SpaceX launches its 500th Falcon 9 rocket")\', \'score\': 0.850382}, {\'title\': \'Next Spaceflight | Rocket Launch Schedule\', \'url\': \'https://nextspaceflight.com/\', \'content\': \'Next Spaceflight | Rocket Launch Schedule\\n\\n===============\\n\\nNEXT SPACEFLIGHTLaunchesEventsStarshipRocketsReuseLocations\\n\\nNEXT SPACEFLIGHTImage 1 LaunchesImage 2 EventsImage 3 StarshipImage 4 RocketsImage 5 ReuseImage 6 Locations\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Dror-1? ("Commercial GTO 1")\\n\\n ASDS \\n\\nSun Jul 13, 2025 04:31 UTC\\n\\nSLC-40, Cape Canaveral SFS, Florida, USA \\n\\nDetails\\n\\n SpaceX \\n\\n##### Falcon 9 Block 5 | Starlink Group 15-2\\n\\n OCISLY \\n\\nMon Jul 14, 2025 02:27 UTC [...] SLC-4E, Vandenberg SFB, California, USA \\n\\nDetails\\n\\n CASC \\n\\n##### Long March 7 | Tianzhou 9\\n\\nMon Jul 14, 2025 21:40 UTC\\n\\nLC-201, Wenchang Space Launch Site, China \\n\\nDetails\\n\\nAll LaunchesSpaceXRocket LabBlue OriginULAArianespaceISRORoscosmos\\n\\nImage 7: Get it on Google Play\\n\\nImage 8: Get it on the App Store\\n\\n### Latest News\\n\\nImage 9: Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\\n\\n##### Halfway through 2025, SpaceX breaks Falcon records and struggles with Starship\', \'score\': 0.8437023}, {\'title\': \'Space Launch Schedule & Live Videos: Stream Rockets Launches\', \'url\': \'https://www.spacelaunchschedule.com/\', \'content\': \'Falcon 9 Block 5 --------------------------------------------\\n### SpaceX\\n\\n Date/Time May Change \\n\\n Sun • Jul 13th, 2025\\n\\n 4:31 AM UTC \\n\\n Cape Canaveral SFS, FL, USA \\n\\nFalcon 9 Block 5 -------- ...
